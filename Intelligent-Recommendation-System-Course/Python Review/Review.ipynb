# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
countries = ['Spain', 'France', 'Germany', 'Italy']
capitals = ['Madrid', 'Paris', 'Berlin', 'Rome']

germany_index = countries.index('Germany')

print('The capital of Germany is {}'.format(capitals[germany_index]) + '.')
# Out:
# The capital of Germany is Berlin.

# %%
europe = {
    'Spain':'Madrid', 
    'France':'Paris', 
    'Germany':'Berlin', 
    'Italy':'Rome'
}

print(europe)
# Out:
# {'Spain': 'Madrid', 'France': 'Paris', 'Germany': 'Berlin', 'Italy': 'Rome'}

# %%
print(europe.keys())
# Out:
# dict_keys(['Spain', 'France', 'Germany', 'Italy'])

# %%
print(europe.values())
# Out:
# dict_values(['Madrid', 'Paris', 'Berlin', 'Rome'])

# %%
print(europe['Spain'])
# Out:
# Madrid

# %%
europe['UAE'] = 'Abu Dhabi'

# %%
print(europe)
# Out:
# {'Spain': 'Madrid', 'France': 'Paris', 'Germany': 'Berlin', 'Italy': 'Rome', 'UAE': 'Abu Dhabi'}

# %%
print('UAE' in europe)
# Out:
# True

# %%
europe = { 
    'Spain': { 
        'capital':'Madrid', 
        'population': 46.77,
    },
    'France': { 
        'capital':'Paris', 
        'population': 66.03,
    },
    'Germany': { 
        'capital':'Berlin', 
        'population': 80.62,
    },
    'Italy': { 
        'capital':'Rome', 
        'population': 55.89,
    } 
}

# %%
print(europe['France'].keys())
print(europe['France'].values())
# Out:
# dict_keys(['capital', 'population'])
# dict_values(['Paris', 66.03])

# %%
print(europe['France']['capital'])
print(europe['France']['population'])
# Out:
# Paris
# 66.03

# %%
data = {
    'capital': 'Warsaw',
    'population': 59.83
}

europe['Poland'] = data

# %%
print(europe)
# Out:
# {'Spain': {'capital': 'Madrid', 'population': 46.77}, 'France': {'capital': 'Paris', 'population': 66.03}, 'Germany': {'capital': 'Berlin', 'population': 80.62}, 'Italy': {'capital': 'Rome', 'population': 55.89}, 'Poland': {'capital': 'Warsaw', 'population': 59.83}}

# %%
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
drive_right = [True, False, False, False, True, True, True]
cars_per_capita = [809, 731, 588, 18, 200, 70, 45]\

cars_dict = {
    'country': names, 
    'drives_right': drive_right, 
    'cars_per_cap': cars_per_capita,
}

# %%
print(cars_dict['country'])
print(cars_dict['drives_right'])
print(cars_dict['cars_per_cap'])
# Out:
# ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
# [True, False, False, False, True, True, True]
# [809, 731, 588, 18, 200, 70, 45]

# %%
cars_df = pd.DataFrame(cars_dict)
print(cars_df)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %%
cars_df.values
# Out:
# array([['United States', True, 809],
#        ['Australia', False, 731],
#        ['Japan', False, 588],
#        ['India', False, 18],
#        ['Russia', True, 200],
#        ['Morocco', True, 70],
#        ['Egypt', True, 45]], dtype=object)

# %%
cars_df.columns.values
# Out:
# array(['country', 'drives_right', 'cars_per_cap'], dtype=object)

# %%
cars_df.index.values
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
homelessness_data = pd.read_csv('homelessness.csv')

# %%
homelessness_data.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
homelessness_data.tail()
# Out:
#     Unnamed: 0              region          state  individuals  \
# 46          46      South Atlantic       Virginia       3928.0
# 47          47             Pacific     Washington      16424.0
# 48          48      South Atlantic  West Virginia       1021.0
# 49          49  East North Central      Wisconsin       2740.0
# 50          50            Mountain        Wyoming        434.0
#
#     family_members  state_pop
# 46          2047.0    8501286
# 47          5880.0    7523869
# 48           222.0    1804291
# 49          2167.0    5807406
# 50           205.0     577601

# %%
homelessness_data = pd.read_csv('homelessness.csv', index_col=0) # Removes the first col

# %%
homelessness_data.head()
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588

# %%
homelessness_data.shape
# Out:
# (51, 5)

# %%
homelessness_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     object
#  1   state           51 non-null     object
#  2   individuals     51 non-null     float64
#  3   family_members  51 non-null     float64
#  4   state_pop       51 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.4+ KB

# %%
homelessness_data.describe()
# Out:
#          individuals  family_members     state_pop
# count      51.000000       51.000000  5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06
# std     15991.025083     7805.411811  7.327258e+06
# min       434.000000       75.000000  5.776010e+05
# 25%      1446.500000      592.000000  1.777414e+06
# 50%      3082.000000     1482.000000  4.461153e+06
# 75%      6781.500000     3196.000000  7.340946e+06
# max    109008.000000    52070.000000  3.946159e+07

# %%
homelessness_data.describe(include='all')
# Out:
#                 region    state    individuals  family_members     state_pop
# count               51       51      51.000000       51.000000  5.100000e+01
# unique               9       51            NaN             NaN           NaN
# top     South Atlantic  Alabama            NaN             NaN           NaN
# freq                 9        1            NaN             NaN           NaN
# mean               NaN      NaN    7225.784314     3504.882353  6.405637e+06
# std                NaN      NaN   15991.025083     7805.411811  7.327258e+06
# min                NaN      NaN     434.000000       75.000000  5.776010e+05
# 25%                NaN      NaN    1446.500000      592.000000  1.777414e+06
# 50%                NaN      NaN    3082.000000     1482.000000  4.461153e+06
# 75%                NaN      NaN    6781.500000     3196.000000  7.340946e+06
# max                NaN      NaN  109008.000000    52070.000000  3.946159e+07

# %%
homelessness_individual = homelessness_data.sort_values(['individuals'])

# %%
print(homelessness_individual.head())
# Out:
#                 region         state  individuals  family_members  state_pop
# 50            Mountain       Wyoming        434.0           205.0     577601
# 34  West North Central  North Dakota        467.0            75.0     758080
# 7       South Atlantic      Delaware        708.0           374.0     965479
# 39         New England  Rhode Island        747.0           354.0    1058287
# 45         New England       Vermont        780.0           511.0     624358

# %%
homelessness_family_members = homelessness_data.sort_values(['family_members'], ascending=0)

# %%
print(homelessness_family_members.head())
# Out:
#                 region          state  individuals  family_members  state_pop
# 32        Mid-Atlantic       New York      39827.0         52070.0   19530351
# 4              Pacific     California     109008.0         20964.0   39461588
# 21         New England  Massachusetts       6811.0         13257.0    6882635
# 9       South Atlantic        Florida      21443.0          9587.0   21244317
# 43  West South Central          Texas      19199.0          6111.0   28628666

# %%
homelessness_region_family = homelessness_data.sort_values(['region', 'family_members'], ascending=[True, False])

# %%
print(homelessness_region_family.head())
# Out:
#                 region      state  individuals  family_members  state_pop
# 13  East North Central   Illinois       6752.0          3891.0   12723071
# 35  East North Central       Ohio       6929.0          3320.0   11676341
# 22  East North Central   Michigan       5209.0          3142.0    9984072
# 49  East North Central  Wisconsin       2740.0          2167.0    5807406
# 14  East North Central    Indiana       3776.0          1482.0    6695497

# %%
homelessness_data['region'].value_counts()
# Out:
# region
# South Atlantic        9
# Mountain              8
# West North Central    7
# New England           6
# Pacific               5
# East North Central    5
# East South Central    4
# West South Central    4
# Mid-Atlantic          3
# Name: count, dtype: int64

# %%
homelessness_data['region'].value_counts(normalize=True)
# Out:
# region
# South Atlantic        0.176471
# Mountain              0.156863
# West North Central    0.137255
# New England           0.117647
# Pacific               0.098039
# East North Central    0.098039
# East South Central    0.078431
# West South Central    0.078431
# Mid-Atlantic          0.058824
# Name: proportion, dtype: float64

# %%
homelessness_data['region'].value_counts(normalize=True) * 100
# Out:
# region
# South Atlantic        17.647059
# Mountain              15.686275
# West North Central    13.725490
# New England           11.764706
# Pacific                9.803922
# East North Central     9.803922
# East South Central     7.843137
# West South Central     7.843137
# Mid-Atlantic           5.882353
# Name: proportion, dtype: float64

# %%
np.round(homelessness_data['region'].value_counts(normalize=True) * 100, 2)
# Out:
# region
# South Atlantic        17.65
# Mountain              15.69
# West North Central    13.73
# New England           11.76
# Pacific                9.80
# East North Central     9.80
# East South Central     7.84
# West South Central     7.84
# Mid-Atlantic           5.88
# Name: proportion, dtype: float64

# %%
indiv_df = homelessness_data['individuals']

# %%
print(indiv_df.head())
# Out:
# 0      2570.0
# 1      1434.0
# 2      7259.0
# 3      2280.0
# 4    109008.0
# Name: individuals, dtype: float64

# %%
state_family = homelessness_data[['state', 'family_members']]

# %%
print(state_family.head())
# Out:
#         state  family_members
# 0     Alabama           864.0
# 1      Alaska           582.0
# 2     Arizona          2606.0
# 3    Arkansas           432.0
# 4  California         20964.0

# %%
indiv_state = homelessness_data[['individuals', 'state']]

# %%
print(indiv_state.head())
# Out:
#    individuals       state
# 0       2570.0     Alabama
# 1       1434.0      Alaska
# 2       7259.0     Arizona
# 3       2280.0    Arkansas
# 4     109008.0  California

# %%
individual_gt_10k = homelessness_data[homelessness_data['individuals'] > 10000]

# %%
print(individual_gt_10k.head())
# Out:
#                 region       state  individuals  family_members  state_pop
# 4              Pacific  California     109008.0         20964.0   39461588
# 9       South Atlantic     Florida      21443.0          9587.0   21244317
# 32        Mid-Atlantic    New York      39827.0         52070.0   19530351
# 37             Pacific      Oregon      11139.0          3337.0    4181886
# 43  West South Central       Texas      19199.0          6111.0   28628666

# %%
mountain_region = homelessness_data[homelessness_data['region'] == 'Mountain']

# %%
print(mountain_region.head())
# Out:
#       region     state  individuals  family_members  state_pop
# 2   Mountain   Arizona       7259.0          2606.0    7158024
# 5   Mountain  Colorado       7607.0          3250.0    5691287
# 12  Mountain     Idaho       1297.0           715.0    1750536
# 26  Mountain   Montana        983.0           422.0    1060665
# 28  Mountain    Nevada       7058.0           486.0    3027341

# %%
family_1t_1k_pacific = homelessness_data[
    (homelessness_data['family_members'] < 1000) & 
    (homelessness_data['region'] == 'Pacific')
]

# %%
print(family_1t_1k_pacific.head())
# Out:
#     region   state  individuals  family_members  state_pop
# 1  Pacific  Alaska       1434.0           582.0     735139

# %%
south_mid_atlantic = homelessness_data[
   (homelessness_data['region'] == "South Atlantic") |
   (homelessness_data['region'] == "Mid-Atlantic")]

# %%
print(south_mid_atlantic.head())
# Out:
#             region                 state  individuals  family_members  \
# 7   South Atlantic              Delaware        708.0           374.0
# 8   South Atlantic  District of Columbia       3770.0          3134.0
# 9   South Atlantic               Florida      21443.0          9587.0
# 10  South Atlantic               Georgia       6943.0          2556.0
# 20  South Atlantic              Maryland       4914.0          2230.0
#
#     state_pop
# 7      965479
# 8      701547
# 9    21244317
# 10   10511131
# 20    6035802

# %%
mojave = ['California', 'Arizona', 'Nevada', 'Utah']

# %%
mojave_homelessness = homelessness_data[homelessness_data['state'].isin(mojave)]

# %%
print(mojave_homelessness.head())
# Out:
#       region       state  individuals  family_members  state_pop
# 2   Mountain     Arizona       7259.0          2606.0    7158024
# 4    Pacific  California     109008.0         20964.0   39461588
# 28  Mountain      Nevada       7058.0           486.0    3027341
# 44  Mountain        Utah       1904.0           972.0    3153550

# %%
homelessness_data['total'] = homelessness_data['individuals'] + homelessness_data['family_members']

# %%
print(homelessness_data.head())
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588
#
#       total
# 0    3434.0
# 1    2016.0
# 2    9865.0
# 3    2712.0
# 4  129972.0

# %%
homelessness_data['proportion_individuals'] = homelessness_data['individuals'] / (homelessness_data['total'])

# %%
print(homelessness_data['proportion_individuals'].head())
# Out:
# 0    0.748398
# 1    0.711310
# 2    0.735834
# 3    0.840708
# 4    0.838704
# Name: proportion_individuals, dtype: float64

# %%
print(homelessness_data.head())
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588
#
#       total  proportion_individuals
# 0    3434.0                0.748398
# 1    2016.0                0.711310
# 2    9865.0                0.735834
# 3    2712.0                0.840708
# 4  129972.0                0.838704

# %%
df = homelessness_data.copy()
df['homeless_indiv_per_state'] = df['individuals'] / df['state_pop'] * 10000

# state with the highest rate
print(df[['state', 'homeless_indiv_per_state']].sort_values('homeless_indiv_per_state', ascending=False).head())
# Out:
#                    state  homeless_indiv_per_state
# 8   District of Columbia                 53.738381
# 11                Hawaii                 29.079406
# 4             California                 27.623825
# 37                Oregon                 26.636307
# 28                Nevada                 23.314189

# %%
region_data = homelessness_data.set_index('region')

# %%
region_data.head()
# Out:
#                          state  individuals  family_members  state_pop  \
# region
# East South Central     Alabama       2570.0           864.0    4887681
# Pacific                 Alaska       1434.0           582.0     735139
# Mountain               Arizona       7259.0          2606.0    7158024
# West South Central    Arkansas       2280.0           432.0    3009733
# Pacific             California     109008.0         20964.0   39461588
#
#                        total  proportion_individuals
# region
# East South Central    3434.0                0.748398
# Pacific               2016.0                0.711310
# Mountain              9865.0                0.735834
# West South Central    2712.0                0.840708
# Pacific             129972.0                0.838704

# %%
region_data.loc[:, ['individuals', 'state_pop']]
# Out:
#                     individuals  state_pop
# region
# East South Central       2570.0    4887681
# Pacific                  1434.0     735139
# Mountain                 7259.0    7158024
# West South Central       2280.0    3009733
# Pacific                109008.0   39461588
# Mountain                 7607.0    5691287
# New England              2280.0    3571520
# South Atlantic            708.0     965479
# South Atlantic           3770.0     701547
# South Atlantic          21443.0   21244317
# South Atlantic           6943.0   10511131
# Pacific                  4131.0    1420593
# Mountain                 1297.0    1750536
# East North Central       6752.0   12723071
# East North Central       3776.0    6695497
# West North Central       1711.0    3148618
# West North Central       1443.0    2911359
# East South Central       2735.0    4461153
# West South Central       2540.0    4659690
# New England              1450.0    1339057
# South Atlantic           4914.0    6035802
# ...

# %%
homelessness_data.head()
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588
#
#       total  proportion_individuals
# 0    3434.0                0.748398
# 1    2016.0                0.711310
# 2    9865.0                0.735834
# 3    2712.0                0.840708
# 4  129972.0                0.838704

# %%
homelessness_data.iloc[5]
# Out:
# region                    Mountain
# state                     Colorado
# individuals                 7607.0
# family_members              3250.0
# state_pop                  5691287
# total                      10857.0
# proportion_individuals    0.700654
# Name: 5, dtype: object

# %%
homelessness_data.iloc[5, :]
# Out:
# region                    Mountain
# state                     Colorado
# individuals                 7607.0
# family_members              3250.0
# state_pop                  5691287
# total                      10857.0
# proportion_individuals    0.700654
# Name: 5, dtype: object

# %%
homelessness_data.iloc[5, 0:4]
# Out:
# region            Mountain
# state             Colorado
# individuals         7607.0
# family_members      3250.0
# Name: 5, dtype: object

# %%
homelessness_data.iloc[:, 1:3]
# Out:
#                    state  individuals
# 0                Alabama       2570.0
# 1                 Alaska       1434.0
# 2                Arizona       7259.0
# 3               Arkansas       2280.0
# 4             California     109008.0
# 5               Colorado       7607.0
# 6            Connecticut       2280.0
# 7               Delaware        708.0
# 8   District of Columbia       3770.0
# 9                Florida      21443.0
# 10               Georgia       6943.0
# 11                Hawaii       4131.0
# 12                 Idaho       1297.0
# 13              Illinois       6752.0
# 14               Indiana       3776.0
# 15                  Iowa       1711.0
# 16                Kansas       1443.0
# 17              Kentucky       2735.0
# 18             Louisiana       2540.0
# 19                 Maine       1450.0
# 20              Maryland       4914.0
# 21         Massachusetts       6811.0
# 22              Michigan       5209.0
# 23             Minnesota       3993.0
# ...

# %%
homelessness_data['individuals'].mean()
# Out:
# 7225.78431372549

# %%
homelessness_data['individuals'].max()
# Out:
# 109008.0

# %%
homelessness_data.max(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 homelessness_data.max(axis=1)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\frame.py:11656, in DataFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11648 @doc(make_doc("max", ndim=2))
#   11649 def max(
#   11650     self,
#    (...)
#   11654     **kwargs,
#   11655 ):
# > 11656     result = super().max(axis, skipna, numeric_only, **kwargs)
#   11657     if isinstance(result, Series):
#   11658         result = result.__finalize__(self, method="max")
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\generic.py:12404, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   12397 def max(
#   12398     self,
#   12399     axis: Axis | None = 0,
#    (...)
#   12402     **kwargs,
#   12403 ):
# > 12404     return self._stat_function(
# ...

# %%
homelessness_data.iloc[:, 2:].max(axis=1)
# Out:
# 0      4887681.0
# 1       735139.0
# 2      7158024.0
# 3      3009733.0
# 4     39461588.0
# 5      5691287.0
# 6      3571520.0
# 7       965479.0
# 8       701547.0
# 9     21244317.0
# 10    10511131.0
# 11     1420593.0
# 12     1750536.0
# 13    12723071.0
# 14     6695497.0
# 15     3148618.0
# 16     2911359.0
# 17     4461153.0
# 18     4659690.0
# 19     1339057.0
# 20     6035802.0
# 21     6882635.0
# 22     9984072.0
# 23     5606249.0
# 24     2981020.0
# 25     6121623.0
# 26     1060665.0
# 27     1925614.0
# 28     3027341.0
# 29     1353465.0
# 30     8886025.0
# 31     2092741.0
# 32    19530351.0
# 33    10381615.0
# 34      758080.0
# 35    11676341.0
# 36     3940235.0
# 37     4181886.0
# 38    12800922.0
# 39     1058287.0
# 40     5084156.0
# 41      878698.0
# 42     6771631.0
# 43    28628666.0
# 44     3153550.0
# 45      624358.0
# 46     8501286.0
# 47     7523869.0
# 48     1804291.0
# 49     5807406.0
# 50      577601.0
# dtype: float64

# %%
homelessness_data['individuals'].min()
# Out:
# 434.0

# %%
homelessness_data['individuals'].var()
# Out:
# 255712883.21254897

# %%
homelessness_data['individuals'].std()
# Out:
# 15991.025083231812

# %%
homelessness_data_missing = pd.read_csv('homelessness_missing.csv')

# %%
homelessness_data_missing.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#     state_pop
# 0   4887681.0
# 1    735139.0
# 2   7158024.0
# 3   3009733.0
# 4  39461588.0

# %%
homelessness_data_missing.isnull()
# Out:
#     Unnamed: 0  region  state  individuals  family_members  state_pop
# 0        False   False  False        False           False      False
# 1        False   False  False        False           False      False
# 2        False   False  False        False           False      False
# 3        False   False  False        False           False      False
# 4        False   False  False        False           False      False
# 5        False   False  False        False           False      False
# 6        False   False  False        False           False      False
# 7        False   False  False        False           False      False
# 8        False   False  False        False           False      False
# 9        False   False  False        False           False      False
# 10       False   False  False        False           False      False
# 11       False   False  False        False           False      False
# ...

# %%
homelessness_data_missing.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 homelessness_data_missing.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
homelessness_data_missing.isnull.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 homelessness_data_missing.isnull.sum(axis=1)
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
homelessness_data_missing['individuals'] = homelessness_data_missing['individuals'].fillna(
    homelessness_data_missing['individuals'].mean()
)

# %%
homelessness_data_missing.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 homelessness_data_missing.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
columns_missing_values = ['individuals', 'family_members', 'state_pop']

# %%
homelessness_data_missing[columns_missing_values] = homelessness_data_missing[columns_missing_values].apply(
    lambda col: col.fillna(col.mean())
)

# %%
homelessness_data_missing.isnull().sum()
# Out:
# Unnamed: 0        0
# region            0
# state             0
# individuals       0
# family_members    0
# state_pop         0
# dtype: int64

# %%
homelessness_data.groupby(['region']).size()
# Out:
# region
# East North Central    5
# East South Central    4
# Mid-Atlantic          3
# Mountain              8
# New England           6
# Pacific               5
# South Atlantic        9
# West North Central    7
# West South Central    4
# dtype: int64

# %%
homelessness_data.groupby(['region'])[['individuals', 'family_members']].mean()
# Out:
#                      individuals  family_members
# region
# East North Central   5081.200000     2800.400000
# East South Central   3117.000000      972.250000
# Mid-Atlantic        18012.666667    20256.333333
# Mountain             3561.375000     1157.250000
# New England          2150.500000     2916.500000
# Pacific             28427.200000     6632.400000
# South Atlantic       5806.666667     2646.444444
# West North Central   1995.857143     1177.428571
# West South Central   6710.500000     2027.500000

# %%
homelessness_data.groupby(['region'])[['individuals', 'family_members']].max()
# Out:
#                     individuals  family_members
# region
# East North Central       6929.0          3891.0
# East South Central       6139.0          1744.0
# Mid-Atlantic            39827.0         52070.0
# Mountain                 7607.0          3250.0
# New England              6811.0         13257.0
# Pacific                109008.0         20964.0
# South Atlantic          21443.0          9587.0
# West North Central       3993.0          3250.0
# West South Central      19199.0          6111.0

# %%
homelessness_data.groupby(['region'])[['individuals', 'family_members']].min()
# Out:
#                     individuals  family_members
# region
# East North Central       2740.0          1482.0
# East South Central       1024.0           328.0
# Mid-Atlantic             6048.0          3350.0
# Mountain                  434.0           205.0
# New England               747.0           354.0
# Pacific                  1434.0           582.0
# South Atlantic            708.0           222.0
# West North Central        467.0            75.0
# West South Central       2280.0           432.0

# %%
homelessness_data.groupby(['region'])[['individuals', 'family_members']].mean().reset_index()
# Out:
#                region   individuals  family_members
# 0  East North Central   5081.200000     2800.400000
# 1  East South Central   3117.000000      972.250000
# 2        Mid-Atlantic  18012.666667    20256.333333
# 3            Mountain   3561.375000     1157.250000
# 4         New England   2150.500000     2916.500000
# 5             Pacific  28427.200000     6632.400000
# 6      South Atlantic   5806.666667     2646.444444
# 7  West North Central   1995.857143     1177.428571
# 8  West South Central   6710.500000     2027.500000

# %%
homelessness_data.groupby(['region'])[['individuals', 'family_members']].mean().reset_index().sort_values('individuals')
# Out:
#                region   individuals  family_members
# 7  West North Central   1995.857143     1177.428571
# 4         New England   2150.500000     2916.500000
# 1  East South Central   3117.000000      972.250000
# 3            Mountain   3561.375000     1157.250000
# 0  East North Central   5081.200000     2800.400000
# 6      South Atlantic   5806.666667     2646.444444
# 8  West South Central   6710.500000     2027.500000
# 2        Mid-Atlantic  18012.666667    20256.333333
# 5             Pacific  28427.200000     6632.400000

# %%
homelessness_data.groupby(['region', 'state'])['individuals'].max()
# Out:
# region              state
# East North Central  Illinois                  6752.0
#                     Indiana                   3776.0
#                     Michigan                  5209.0
#                     Ohio                      6929.0
#                     Wisconsin                 2740.0
# East South Central  Alabama                   2570.0
#                     Kentucky                  2735.0
#                     Mississippi               1024.0
#                     Tennessee                 6139.0
# Mid-Atlantic        New Jersey                6048.0
#                     New York                 39827.0
#                     Pennsylvania              8163.0
# Mountain            Arizona                   7259.0
#                     Colorado                  7607.0
#                     Idaho                     1297.0
#                     Montana                    983.0
#                     Nevada                    7058.0
# ...

# %%
homelessness_data['region'].value_counts()
# Out:
# region
# South Atlantic        9
# Mountain              8
# West North Central    7
# New England           6
# Pacific               5
# East North Central    5
# East South Central    4
# West South Central    4
# Mid-Atlantic          3
# Name: count, dtype: int64

# %%
homelessness_data['region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='region'>

# %%
plt.figure(figsize=(15, 8))
data = homelessness_data['region'].value_counts()
data.plot(kind='bar', x='region', y='count')
plt.xlabel('Region')
plt.ylabel('Number of States')
plt.title('Number of States in Each Region')
plt.show()

# %%
homelessness_data['individuals'].plot(kind='hist', bins=10, edgecolor='black')
plt.xlabel('Homelessness')
plt.ylabel('Number of States')
plt.title('Distribution of Homelessness (Individuals) Across the US')
plt.show()

# %%
plt.figure(figsize=(10, 8))
homelessness_data['individuals'].plot(kind='box')
plt.ylabel('Homelessness')
plt.title('Distribution of Homelessness (Individuals) Across the US')
plt.show()

# %%
temperatures_data = pd.read_csv('temperatures.csv', index_col=0)

# %%
temperatures_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16500 entries, 0 to 16499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        16500 non-null  object
#  1   city        16500 non-null  object
#  2   country     16500 non-null  object
#  3   avg_temp_c  16407 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 644.5+ KB

# %%
temperatures_data['data'] = pd.to_datetime(temperatures_data['date'])

# %%
temperatures_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16500 entries, 0 to 16499
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        16500 non-null  object
#  1   city        16500 non-null  object
#  2   country     16500 non-null  object
#  3   avg_temp_c  16407 non-null  float64
#  4   data        16500 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 773.4+ KB

# %%
print(temperatures_data['date'].max())
# Out:
# 2013-09-01

# %%
print(temperatures_data['date'].min())
# Out:
# 2000-01-01

# %%
temperatures_data['date_plus_1'] = temperatures_data['date'] + pd.Timedelta(days = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[228], line 1
# ----> 1 temperatures_data['date_plus_1'] = temperatures_data['date'] + pd.Timedelta(days = 1)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# ...

# %%
temperatures_data['date_minus_5'] = temperatures_data['date'] - pd.Timedelta(days=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[229], line 1
# ----> 1 temperatures_data['date_minus_5'] = temperatures_data['date'] - pd.Timedelta(days=5)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
# ...

# %%
temperatures_data['date_plus_15'] = temperatures_data['date'] + pd.Timedelta(days=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 temperatures_data['date_plus_15'] = temperatures_data['date'] + pd.Timedelta(days=15)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# ...

# %%
temperatures_data.head()
# Out:
#          date     city        country  avg_temp_c       data
# 0  2000-01-01  Abidjan  Côte D'Ivoire      27.293 2000-01-01
# 1  2000-02-01  Abidjan  Côte D'Ivoire      27.685 2000-02-01
# 2  2000-03-01  Abidjan  Côte D'Ivoire      29.061 2000-03-01
# 3  2000-04-01  Abidjan  Côte D'Ivoire      28.162 2000-04-01
# 4  2000-05-01  Abidjan  Côte D'Ivoire      27.547 2000-05-01

# %%
temperatures_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16500 entries, 0 to 16499
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        16500 non-null  object
#  1   city        16500 non-null  object
#  2   country     16500 non-null  object
#  3   avg_temp_c  16407 non-null  float64
#  4   data        16500 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 773.4+ KB

# %%
temperatures_data['day'] = temperatures_data['date'].dt.day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[233], line 1
# ----> 1 temperatures_data['day'] = temperatures_data['date'].dt.day
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
temperatures_data['month'] = temperatures_data['date'].dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[234], line 1
# ----> 1 temperatures_data['month'] = temperatures_data['date'].dt.month
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\Users\Oroch\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
temperatures_data.head()
# Out:
#          date     city        country  avg_temp_c       data
# 0  2000-01-01  Abidjan  Côte D'Ivoire      27.293 2000-01-01
# 1  2000-02-01  Abidjan  Côte D'Ivoire      27.685 2000-02-01
# 2  2000-03-01  Abidjan  Côte D'Ivoire      29.061 2000-03-01
# 3  2000-04-01  Abidjan  Côte D'Ivoire      28.162 2000-04-01
# 4  2000-05-01  Abidjan  Côte D'Ivoire      27.547 2000-05-01
